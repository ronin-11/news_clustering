# %%
import csv

# Open the CSV file and read it line by line
rows = []
with open('sport_articles.txt', 'r', encoding='utf-8') as file:
    csv_reader = csv.reader(file, delimiter='\t')
    for row in csv_reader:
        rows.append(row)

# Convert the list of rows to a DataFrame
df = pd.DataFrame(rows)

# %%
df
# Out:
#                                                      0
# 0        Title: ZRA hands over classroom block, clinic
# 1    URL: https://www.herald.co.zw/zra-hands-over-c...
# 2                                             Content:
# 3                      Walter Nyamukondiwa in HURUNGWE
# 4                                                 None
# ..                                                 ...
# 818                                               None
# 819                    Goromonzi 8-12 Milton Boys High
# 820                                               None
# 821             Nhowe Mission 36-14 Morgan High School
# 822                                               None
#
# [823 rows x 1 columns]

# %%
import pandas as pd

# Define a function to parse the file
def parse_text_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = {'Title': [], 'URL': [], 'Content': []}
        current_section = None
        content = []

        for line in file:
            line = line.strip()
            if line.startswith('Title:'):
                if content:
                    data['Content'].append(' '.join(content))
                    content = []
                current_section = 'Title'
                title = line.replace('Title:', '').strip()
                data['Title'].append(title)
            elif line.startswith('URL:'):
                current_section = 'URL'
                url = line.replace('URL:', '').strip()
                data['URL'].append(url)
            elif line.startswith('Content:'):
                current_section = 'Content'
            elif current_section == 'Content' and line:
                content.append(line)

        # Add the last content block
        if content:
            data['Content'].append(' '.join(content))

    return pd.DataFrame(data)

# Path to your file
file_path = 'sport_articles.txt'
df = parse_text_file(file_path)
print(df.head())
# Out:
#                                               Title  \
# 0            ZRA hands over classroom block, clinic
# 1  Bindura Hospital loses pump and pipes to thieves
# 2                       Warriors to play at Orlando
# 3            ZRA hands over classroom block, clinic
# 4
#
#                                                  URL  \
# 0  https://www.herald.co.zw/zra-hands-over-classr...
# 1  https://www.herald.co.zw/bindura-hospital-lose...
# 2  https://www.herald.co.zw/warriors-to-play-at-o...
# 3  https://www.herald.co.zw/zra-hands-over-classr...
# 4   https://www.herald.co.zw/workers-efforts-hailed/
#
#                                              Content
# 0  Walter Nyamukondiwa in HURUNGWE The Zambezi Ri...
# 1  Fungai Lupande Mashonaland Central Bureau A pr...
# 2  Sports Reporter ZIMBABWE will play their next ...
# 3  Walter Nyamukondiwa in HURUNGWE The Zambezi Ri...
# 4  Wallace Ruzvidzo Herald Reporter President Mna...

# %%
df
# Out:
#                                                 Title  \
# 0              ZRA hands over classroom block, clinic
# 1    Bindura Hospital loses pump and pipes to thieves
# 2                         Warriors to play at Orlando
# 3              ZRA hands over classroom block, clinic
# 4
# 5
# 6
# 7                         Warriors to play at Orlando
# 8                ZIFA slam door on Mapeza, Grobbelaar
# 9                      Chaminuka linked to Green Fuel
# 10             World Cup heartbreak for Lady Chevrons
# 11  As fate would have it, a former cook now capta...
# 12                     Karate for AUSC Region 5 Games
# 13                         Zim Star makes waves in US
# 14                    Mangombe backs his Namibian man
# 15               Chess star eyes African Youth Champs
# 16  Nadal bids farewell to Madrid after defeat by ...
# 17  Kane reveals Bellingham’s mind games before pe...
# 18  LIV Golf books Individual Championship for Sep...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Title    22 non-null     object
#  1   URL      22 non-null     object
#  2   Content  22 non-null     object
# dtypes: object(3)
# memory usage: 656.0+ bytes

# %%
import pandas as pd

# Define a function to parse the file
def parse_text_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = {'Title': [], 'URL': [], 'Content': []}
        current_section = None
        content = []

        for line in file:
            line = line.strip()
            if line.startswith('Title:'):
                if content:
                    data['Content'].append(' '.join(content))
                    content = []
                current_section = 'Title'
                title = line.replace('Title:', '').strip()
                data['Title'].append(title)
            elif line.startswith('URL:'):
                current_section = 'URL'
                url = line.replace('URL:', '').strip()
                data['URL'].append(url)
            elif line.startswith('Content:'):
                current_section = 'Content'
            elif current_section == 'Content' and line:
                content.append(line)

        # Add the last content block
        if content:
            data['Content'].append(' '.join(content))

    return pd.DataFrame(data)

# Path to your file
file_path = 'sport_articles.txt'
df = parse_text_file(file_path)

# Save the DataFrame to a CSV file
csv_file_path = 'parsed_sport_articles.csv'
df.to_csv(csv_file_path, index=False)

print("Data saved to CSV file successfully!")
# Out:
# Data saved to CSV file successfully!

# %%
df =pd.read_csv('parsed_sport_articles.csv')
df
# Out:
#                                                 Title  \
# 0              ZRA hands over classroom block, clinic
# 1    Bindura Hospital loses pump and pipes to thieves
# 2                         Warriors to play at Orlando
# 3              ZRA hands over classroom block, clinic
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                         Warriors to play at Orlando
# 8                ZIFA slam door on Mapeza, Grobbelaar
# 9                      Chaminuka linked to Green Fuel
# 10             World Cup heartbreak for Lady Chevrons
# 11  As fate would have it, a former cook now capta...
# 12                     Karate for AUSC Region 5 Games
# 13                         Zim Star makes waves in US
# 14                    Mangombe backs his Namibian man
# 15               Chess star eyes African Youth Champs
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# Load your data
data = pd.read_csv('parsed_sport_articles.csv')

# Extract features
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(data['Content'])

# Perform clustering
kmeans = KMeans(n_clusters=5, random_state=0)  # Adjust the number of clusters
data['Cluster'] = kmeans.fit_predict(X)

# Save the clustered data
data.to_csv('clustered_sport_articles.csv', index=False)

# %%
clust =pd.read_csv('clustered_sport_articles.csv')
clust
# Out:
#                                                 Title  \
# 0              ZRA hands over classroom block, clinic
# 1    Bindura Hospital loses pump and pipes to thieves
# 2                         Warriors to play at Orlando
# 3              ZRA hands over classroom block, clinic
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                         Warriors to play at Orlando
# 8                ZIFA slam door on Mapeza, Grobbelaar
# 9                      Chaminuka linked to Green Fuel
# 10             World Cup heartbreak for Lady Chevrons
# 11  As fate would have it, a former cook now capta...
# 12                     Karate for AUSC Region 5 Games
# 13                         Zim Star makes waves in US
# 14                    Mangombe backs his Namibian man
# 15               Chess star eyes African Youth Champs
# ...
